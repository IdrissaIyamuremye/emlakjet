# %%
import pandas as pd 
import numpy as  np

# %%
emlakjet_data = pd.read_csv("emlakjet_20251214_214758.csv")
emlakjet_data.shape
# Out:
# (1289, 13)

# %%
emlakjet_data.columns
# Out:
# Index(['Tarih', 'Fiyat', 'Fiyat_Sayisal', 'Fiyat_Per_m2', 'Semt', 'Mahalle',
#        'Konum', 'Oda_Sayisi', 'Brut_Alan_m2', 'Brut_Alan_m2_Numeric', 'Kat',
#        'Detaylar', 'URL'],
#       dtype='object')

# %%
emlakjet_dataset= emlakjet_data.copy()
df = emlakjet_data.drop(columns=["Semt", "Detaylar", "URL"])
df = df.dropna(axis=1, how="all")
df
# Out:
#                     Tarih      Fiyat  Fiyat_Sayisal  Fiyat_Per_m2  \
# 0     2025-12-14 21:35:49  27.500 TL           27.5          0.21
# 1     2025-12-14 21:35:49  32.000 TL           32.0          0.29
# 2     2025-12-14 21:35:49  20.000 TL           20.0          0.33
# 3     2025-12-14 21:35:49  52.000 TL           52.0          0.69
# 4     2025-12-14 21:35:50  50.000 TL           50.0          0.83
# ...                   ...        ...            ...           ...
# 1284  2025-12-14 21:47:51  29.000 TL           29.0          0.64
# 1285  2025-12-14 21:47:51  45.000 TL           45.0          0.56
# 1286  2025-12-14 21:47:52  20.000 TL           20.0          0.36
# 1287  2025-12-14 21:47:52  49.000 TL           49.0          0.21
# 1288  2025-12-14 21:47:52  27.000 TL           27.0          0.49
#
#                                        Konum Oda_Sayisi  Brut_Alan_m2  \
# 0           Sultanbeyli - Hamidiye Mahallesi        3+1           130
# ...

# %%
df.isna().sum()
# Out:
# Tarih                     0
# Fiyat                     0
# Fiyat_Sayisal            28
# Fiyat_Per_m2             28
# Konum                     0
# Oda_Sayisi                9
# Brut_Alan_m2              0
# Brut_Alan_m2_Numeric      0
# Kat                     119
# dtype: int64

# %%
len(df)
# Out:
# 1289
